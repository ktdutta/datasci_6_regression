# %% [markdown]
# ## Installing Packages

# %%
# !pip install ucimlrepo

# %% [markdown]
# ## Importing Packages

# %%
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.stats import shapiro
from statsmodels.stats.diagnostic import linear_rainbow
from statsmodels.stats.diagnostic import het_goldfeldquandt

# %% [markdown]
# ## Simple Linear Regression

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
breast_cancer_wisconsin_diagnostic = fetch_ucirepo(id=17)

# data (as pandas dataframes)
X = breast_cancer_wisconsin_diagnostic.data.features
y = breast_cancer_wisconsin_diagnostic.data.targets

# metadata
print(breast_cancer_wisconsin_diagnostic.metadata)

# variable information
print(breast_cancer_wisconsin_diagnostic.variables)
# Out:
# {'uci_id': 17, 'name': 'Breast Cancer Wisconsin (Diagnostic)', 'repository_url': 'https://archive.ics.uci.edu/dataset/17/breast+cancer+wisconsin+diagnostic', 'data_url': 'https://archive.ics.uci.edu/static/public/17/data.csv', 'abstract': 'Diagnostic Wisconsin Breast Cancer Database.', 'area': 'Health and Medicine', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 569, 'num_features': 30, 'feature_types': ['Real'], 'demographics': [], 'target_col': ['Diagnosis'], 'index_col': ['ID'], 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 1993, 'last_updated': 'Fri Nov 03 2023', 'dataset_doi': '10.24432/C5DW2B', 'creators': ['William Wolberg', 'Olvi Mangasarian', 'Nick Street', 'W. Street'], 'intro_paper': {'title': 'Nuclear feature extraction for breast tumor diagnosis', 'authors': 'W. Street, W. Wolberg, O. Mangasarian', 'published_in': 'Electronic imaging', 'year': 1993, 'url': 'https://www.semanticscholar.org/paper/
# ...

# %%
df = pd.DataFrame(X)
df
# Out:
#      radius1  texture1  perimeter1   area1  smoothness1  compactness1  \
# 0      17.99     10.38      122.80  1001.0      0.11840       0.27760
# 1      20.57     17.77      132.90  1326.0      0.08474       0.07864
# 2      19.69     21.25      130.00  1203.0      0.10960       0.15990
# 3      11.42     20.38       77.58   386.1      0.14250       0.28390
# 4      20.29     14.34      135.10  1297.0      0.10030       0.13280
# ..       ...       ...         ...     ...          ...           ...
# 564    21.56     22.39      142.00  1479.0      0.11100       0.11590
# 565    20.13     28.25      131.20  1261.0      0.09780       0.10340
# 566    16.60     28.08      108.30   858.1      0.08455       0.10230
# 567    20.60     29.33      140.10  1265.0      0.11780       0.27700
# 568     7.76     24.54       47.92   181.0      0.05263       0.04362
#
#      concavity1  concave_points1  symmetry1  fractal_dimension1  ...  radius3  \
# ...

# %% [markdown]
# ### Variables for Analysis
#
# Dependent Variable: "area1" (of cell)
#
# Independent Variable: "radius1" (of cell)

# %%
df.describe()
# Out:
#           radius1    texture1  perimeter1        area1  smoothness1  \
# count  569.000000  569.000000  569.000000   569.000000   569.000000
# mean    14.127292   19.289649   91.969033   654.889104     0.096360
# std      3.524049    4.301036   24.298981   351.914129     0.014064
# min      6.981000    9.710000   43.790000   143.500000     0.052630
# 25%     11.700000   16.170000   75.170000   420.300000     0.086370
# 50%     13.370000   18.840000   86.240000   551.100000     0.095870
# 75%     15.780000   21.800000  104.100000   782.700000     0.105300
# max     28.110000   39.280000  188.500000  2501.000000     0.163400
#
#        compactness1  concavity1  concave_points1   symmetry1  \
# count    569.000000  569.000000       569.000000  569.000000
# mean       0.104341    0.088799         0.048919    0.181162
# std        0.052813    0.079720         0.038803    0.027414
# min        0.019380    0.000000         0.000000    0.106000
# ...

# %%
Y = sm.add_constant(df['area1'])
model = sm.OLS(df['radius1'], Y)
print(Y)
# Out:
#      const   area1
# 0      1.0  1001.0
# 1      1.0  1326.0
# 2      1.0  1203.0
# 3      1.0   386.1
# 4      1.0  1297.0
# ..     ...     ...
# 564    1.0  1479.0
# 565    1.0  1261.0
# 566    1.0   858.1
# 567    1.0  1265.0
# 568    1.0   181.0
#
# [569 rows x 2 columns]

# %%
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                radius1   R-squared:                       0.975
# Model:                            OLS   Adj. R-squared:                  0.975
# Method:                 Least Squares   F-statistic:                 2.200e+04
# Date:                Tue, 05 Dec 2023   Prob (F-statistic):               0.00
# Time:                        06:49:32   Log-Likelihood:                -475.54
# No. Observations:                 569   AIC:                             955.1
# Df Residuals:                     567   BIC:                             963.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.6522      0.050    154.434      0.000       7.555       7.750
# ...

# %% [markdown]
# #### Interpretation

# %%
residuals = results.resid
fitted = results.fittedvalues

# %% [markdown]
# ### Assessing Linearity of Relationship

# %%
stat, p_value = linear_rainbow(results)
print(f"Rainbow Test: stat={stat}, p-value={p_value}")
# Out:
# Rainbow Test: stat=1.1608528302357366, p-value=0.10499078536018355

# %% [markdown]
# #### Interpretation
#
# The p-value is larger than 0.05 and not statistically significant, therefore it can be concluded that there is a linear relationship between the two variables, rejecting the null hypothesis.

# %% [markdown]
# ## Plot Observed vs. Fitted Values

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['radius1'], y=fitted)
plt.xlabel('Observed Values')
plt.ylabel('Fitted Values')
plt.title('Observed vs Fitted Values')
plt.plot([min(df['radius1']), max(df['radius1'])], [min(fitted), max(fitted)], color='orange', linestyle='--')
plt.show()

# %% [markdown]
# ## Assessing Normality of Residuals
#
# ### Shapiro-Wilk Test

# %%
W, p_value = shapiro(residuals)
print(f"Shapiro-Wilk Test: W={W}, p-value={p_value}")
# Out:
# Shapiro-Wilk Test: W=0.7845569849014282, p-value=9.943721132803117e-27

# %%
plt.figure(figsize=(10, 6))
stats.probplot(residuals, plot=plt)
plt.title('Q-Q Plot of Residuals')
plt.show()

# %% [markdown]
# #### Interpretation
#
# The p-value is less than 0.05 and significant, therefore the different levels of independent variables are within a normal distribution.

# %% [markdown]
# ## Assessing the Homogeneity of Variance of the Residuals
#
# ### Goldfeld-Quandt Test

# %%
gq_test = het_goldfeldquandt(residuals, results.model.exog)
print(f"Goldfeld-Quandt Test: F-statistic={gq_test[0]}, p-value={gq_test[1]}")
# Out:
# Goldfeld-Quandt Test: F-statistic=0.9861226587265172, p-value=0.5466749130295332

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=fitted, y=residuals)
plt.axhline(0, color='orange', linestyle='--')
plt.xlabel('Fitted Values')
plt.ylabel('Residuals')
plt.title('Residuals vs Fitted Values')
plt.show()

# %% [markdown]
# #### Interpretation
#
# The p-value is greater than 0.05 and not significant, therefore the variance of the residuals is constant across different levels of the independent variable

# %% [markdown]
# ## Multiple Linear Regression

# %%
df=pd.read_csv('heart_risk.csv')
df
# Out:
#      isMale  isBlack  isSmoker  isDiabetic  isHypertensive  Age  Systolic  \
# 0         1        1         0           1               1   49       101
# 1         0        0         0           1               1   69       167
# 2         0        1         1           1               1   50       181
# 3         1        1         1           1               0   42       145
# 4         0        0         1           0               1   66       134
# ..      ...      ...       ...         ...             ...  ...       ...
# 995       1        0         1           1               1   42       110
# 996       0        1         0           1               0   75       123
# 997       1        1         1           0               1   76       178
# 998       0        1         1           1               0   65       139
# 999       0        1         0           0               0   57       182
#
#      Cholesterol  HDL  Risk
# 0            181   32  11.1
# ...

# %% [markdown]
# ### Cleaning and Understanding Dataset

# %%
import re
def cleaning_columns (df):
    def clean_name(name):
        cleaned_name = re.sub(r'[^a-zA-Z0-9]', '', name)
        return cleaned_name.lower()

    df.columns = [clean_name(col) for col in df.columns]
    return df

df = cleaning_columns(df)
df
# Out:
#      ismale  isblack  issmoker  isdiabetic  ishypertensive  age  systolic  \
# 0         1        1         0           1               1   49       101
# 1         0        0         0           1               1   69       167
# 2         0        1         1           1               1   50       181
# 3         1        1         1           1               0   42       145
# 4         0        0         1           0               1   66       134
# ..      ...      ...       ...         ...             ...  ...       ...
# 995       1        0         1           1               1   42       110
# 996       0        1         0           1               0   75       123
# 997       1        1         1           0               1   76       178
# 998       0        1         1           1               0   65       139
# 999       0        1         0           0               0   57       182
#
#      cholesterol  hdl  risk
# 0            181   32  11.1
# ...

# %%
df.columns
# Out:
# Index(['ismale', 'isblack', 'issmoker', 'isdiabetic', 'ishypertensive', 'age',
#        'systolic', 'cholesterol', 'hdl', 'risk'],
#       dtype='object')

# %% [markdown]
# ### Selection of Variables
#
# Dependent Variable: 'risk'
#
# Independent Variable 1: 'issmoker'
#
# Independent Variable 2: 'age'
#
# Independent Variable 3: 'systolic'
#
# Independent Variable 4: 'cholesterol'
#
# Independent Variable 5: ' hdl'

# %%
risk_predictors = df[['issmoker', 'cholesterol', 'age', 'systolic', 'hdl']]
risk_predictors
# Out:
#      issmoker  cholesterol  age  systolic  hdl
# 0           0          181   49       101   32
# 1           0          155   69       167   59
# 2           1          147   50       181   59
# 3           1          166   42       145   46
# 4           1          199   66       134   63
# ..        ...          ...  ...       ...  ...
# 995         1          175   42       110   67
# 996         0          130   75       123   56
# 997         1          179   76       178   30
# 998         1          169   65       139   66
# 999         0          146   57       182   38
#
# [1000 rows x 5 columns]

# %%
X = sm.add_constant(risk_predictors)
y = df['risk']
model = sm.OLS(y, X)
results = model.fit()

# %%
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   risk   R-squared:                       0.653
# Model:                            OLS   Adj. R-squared:                  0.651
# Method:                 Least Squares   F-statistic:                     374.4
# Date:                Thu, 07 Dec 2023   Prob (F-statistic):          1.16e-225
# Time:                        17:26:50   Log-Likelihood:                -3724.7
# No. Observations:                1000   AIC:                             7461.
# Df Residuals:                     994   BIC:                             7491.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const         -74.7473      3.508    -21.309      0.000     -81.631     -67.864
# ...

# %% [markdown]
# #### Interpretation
#
# The R2 value indicates that 65% of the variation in the dependent variable can be explained by the independent variables. All the p-values for the independent variables are less than 0.05, therefore are significant and indicates a linear relationship.

# %% [markdown]
# ### Assessing Linearity of Relationship

# %%
stat, p_value = linear_rainbow(results)
print(f"Rainbow Test: stat={stat}, p-value={p_value}")
# Out:
# Rainbow Test: stat=0.9447821671285594, p-value=0.7366297467924152

# %% [markdown]
# #### Interpretation
#
# The p-value is greater than 0.05 and not significant which indicates a linear realationship.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif_data = pd.DataFrame()
vif_data['Variable'] = X.columns
vif_data['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print("\nVIF Data:")
print(vif_data)
# Out:
# VIF Data:
#       Variable         VIF
# 0        const  121.528569
# 1     issmoker    1.003763
# 2  cholesterol    1.003872
# 3          age    1.002937
# 4     systolic    1.007289
# 5          hdl    1.002569

# %% [markdown]
# ####Interpretation
#
# The VIF of 1 for all the independent variables indicates that there is no multicollinearity between the variables.

# %% [markdown]
# ### Plot Observed vs. Fitted Values

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x= df['risk'], y= fitted)
plt.xlabel('Observed Values')
plt.ylabel('Fitted Values')
plt.title('Observed vs Fitted Values')
plt.plot([min(df['risk']), max(df['risk'])], [min(fitted), max(fitted)], color='orange', linestyle='--')
plt.show()

# %%
residuals = results.resid
fitted = results.fittedvalues

# %% [markdown]
# ### Assessing Normality of Residuals

# %%
W, p_value = shapiro(residuals)
print(f"Shapiro-Wilk Test: W={W}, p-value={p_value}")
# Out:
# Shapiro-Wilk Test: W=0.9795153737068176, p-value=1.1752546158483312e-10

# %%
plt.figure(figsize=(10, 6))
stats.probplot(residuals, plot=plt)
plt.title('Q-Q Plot of Residuals')
plt.show()

# %% [markdown]
# #### Interpretation
#
# The p-value is less than 0.05 and significant. This sugessts that there is a normal distribution.

# %% [markdown]
# ### Assessing Homogeneity of Variance of the Residuals

# %%
gq_test = het_goldfeldquandt(residuals, results.model.exog)
print(f"Goldfeld-Quandt Test: F-statistic={gq_test[0]}, p-value={gq_test[1]}")
# Out:
# Goldfeld-Quandt Test: F-statistic=1.1531960540149897, p-value=0.056761569813972214

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=fitted, y=residuals)
plt.axhline(0, color='orange', linestyle='--')
plt.xlabel('Fitted Values')
plt.ylabel('Residuals')
plt.title('Residuals vs Fitted Values')
plt.show()

# %% [markdown]
# #### Interpretation
#
# The p-value is greater than 0.05 and is not siginificant. This indicates that the variance of the residuals is constant through out the independent variables.
